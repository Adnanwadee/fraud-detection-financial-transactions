# %% [markdown]
#  **Name : Adnan Wadee Abdullah  159788
# Name : Ammar Atef Alrousan   162141**

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('/content/Online_Payments_Fraud.csv')
data.shape
# Out:
# (6362620, 11)

# %%
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
data.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# There are no null values in our dataset.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in our dataset.

# %% [markdown]
# Checking values for the columns

# %%
data.nameDest.value_counts()
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C1590550415    101
#               ...
# M295304806       1
# M33419717        1
# M1940055334      1
# M335107734       1
# M1757317128      1
# Name: count, Length: 2722362, dtype: int64

# %%
data.nameOrig.value_counts()
# Out:
# nameOrig
# C1530544995    3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
#               ..
# C1567523029    1
# C644777639     1
# C1256645416    1
# C1231536757    1
# C1971151096    1
# Name: count, Length: 6353307, dtype: int64

# %%
data.isFlaggedFraud.value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
data.type.value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
data.isFraud.value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Univariate analysis is used to analyze the data of single variable. Here we will analyze using histplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data.select_dtypes('number')
# Out:
#          step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0           1     9839.64      170136.00       160296.36            0.00
# 1           1     1864.28       21249.00        19384.72            0.00
# 2           1      181.00         181.00            0.00            0.00
# 3           1      181.00         181.00            0.00        21182.00
# 4           1    11668.14       41554.00        29885.86            0.00
# ...       ...         ...            ...             ...             ...
# 6362615   743   339682.13      339682.13            0.00            0.00
# 6362616   743  6311409.28     6311409.28            0.00            0.00
# 6362617   743  6311409.28     6311409.28            0.00        68488.84
# 6362618   743   850002.52      850002.52            0.00            0.00
# 6362619   743   850002.52      850002.52            0.00      6510099.11
#
#          newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
feature=['step','amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

# %%
for i in feature:
    plt.figure(figsize=(12, 6))
    plt.hist(data[i], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f'Distribution of {i}', fontsize=16)
    plt.xlabel(i, fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# We see some outliers in the plots. So we will solve this problem.

# %%
import numpy as np
import matplotlib.pyplot as plt

feature = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']

for i in feature:
    lower = data[i].quantile(0.10)
    upper = data[i].quantile(0.90)
    data[i] = np.where(data[i] < lower, lower, data[i])
    data[i] = np.where(data[i] > upper, upper, data[i])

    skewness = data[i].skew()
    print(f'Feature: {i}')
    print(f'Skewness value: {skewness:.4f}')
    print('-' * 40)

for i in feature:
    plt.figure(figsize=(12, 6))
    plt.hist(data[i], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f'Distribution of {i}', fontsize=16)
    plt.xlabel(i, fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Feature: amount
# Skewness value: 0.8046
# ----------------------------------------
# Feature: oldbalanceOrg
# Skewness value: 2.2494
# ----------------------------------------
# Feature: newbalanceOrig
# Skewness value: 2.2263
# ----------------------------------------
# Feature: oldbalanceDest
# Skewness value: 1.4173
# ----------------------------------------
# Feature: newbalanceDest
# Skewness value: 1.3593
# ----------------------------------------

# %%
data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.640  C1231006815     170136.000
# 1           1   PAYMENT    4501.300  C1666544295      21249.000
# 2           1  TRANSFER    4501.300  C1305486145        181.000
# 3           1  CASH_OUT    4501.300   C840083671        181.000
# 4           1   PAYMENT   11668.140  C2048537720      41554.000
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT  339682.130   C786484425     339682.130
# 6362616   743  TRANSFER  365423.309  C1529008245    1822508.289
# 6362617   743  CASH_OUT  365423.309  C1162922333    1822508.289
# 6362618   743  TRANSFER  365423.309  C1685995037     850002.520
# 6362619   743  CASH_OUT  365423.309  C1280323807     850002.520
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155           0.000           0.000        0
# ...

# %%
data.type.unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
payment = data.type.value_counts()
payment
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
payment.plot(kind='barh', color='skyblue', edgecolor='black', alpha=0.8)

plt.title('Payment Distribution', fontsize=16)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Categories', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x='type', data=data, palette='viridis', edgecolor='black')

plt.title('Count of Transactions by Type', fontsize=16)
plt.xlabel('Transaction Type', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-77648a272d46>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=data, palette='viridis', edgecolor='black')

# %%
cross_tab_result=pd.crosstab(index=data.type,columns=data.isFraud)
cross_tab_result
# Out:
# isFraud         0     1
# type
# CASH_IN   1399284     0
# CASH_OUT  2233384  4116
# DEBIT       41432     0
# PAYMENT   2151495     0
# TRANSFER   528812  4097

# %%
cross_tab_result[1]
# Out:
# type
# CASH_IN        0
# CASH_OUT    4116
# DEBIT          0
# PAYMENT        0
# TRANSFER    4097
# Name: 1, dtype: int64

# %%
cross_tab_result.plot.bar(
    figsize=(8, 5),
    rot=0,
    color=['skyblue', 'lightgreen', 'salmon'],
    edgecolor='black',
    alpha=0.8
)

plt.title('Cross Tabulation Result', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Legend', fontsize=12, title_fontsize=13)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
cross_tab_result[1].plot.bar(
    figsize=(8, 5),
    color='skyblue',
    edgecolor='black',
    alpha=0.8
)

plt.title('Bar Chart for Cross Tabulation (Row/Column 1)', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
cross_tab_result.plot.bar(
    figsize=(8, 5),
    rot=0,
    color=['skyblue', 'lightgreen', 'salmon'],
    edgecolor='black',
    alpha=0.8
)

plt.ylim([3500, 7000])

plt.title('Cross Tabulation Result', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
cross_tab_result
# Out:
# isFraud         0     1
# type
# CASH_IN   1399284     0
# CASH_OUT  2233384  4116
# DEBIT       41432     0
# PAYMENT   2151495     0
# TRANSFER   528812  4097

# %%
cashout= (2233384 + 4116)
cashout_fraud= 4116/(cashout) * 100
cashout_fraud
# Out:
# 0.18395530726256984

# %%
transfer= 528812+4097
transfer_fraud = 4097/(transfer) * 100
transfer_fraud
# Out:
# 0.7687991758442811

# %%
data.amount
# Out:
# 0            9839.640
# 1            4501.300
# 2            4501.300
# 3            4501.300
# 4           11668.140
#               ...
# 6362615    339682.130
# 6362616    365423.309
# 6362617    365423.309
# 6362618    365423.309
# 6362619    365423.309
# Name: amount, Length: 6362620, dtype: float64

# %%
print('Minimum: ',data.amount.min())
print('Maximum: ',data.amount.max())
# Out:
# Minimum:  4501.3
# Maximum:  365423.30900000007

# %%
plt.figure(figsize=(10, 10))

sns.stripplot(
    y=data.amount,
    color='skyblue',
    alpha=0.7,
    jitter=True,
    edgecolor='black',
    linewidth=0.5
)

plt.title('Distribution of Amount', fontsize=16)
plt.ylabel('Amount', fontsize=14)
plt.xlabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))
data.boxplot(column='amount', by='isFraud', grid=False, patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'))

plt.title('Box Plot of Amount by Fraud Status', fontsize=16)
plt.suptitle('')
plt.xlabel('Fraud Status (0 = Not Fraud, 1 = Fraud)', fontsize=14)
plt.ylabel('Amount', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

plt.show()

# %%
data.isFlaggedFraud.value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
flagged_fraud_records = data[(data.isFraud==1) & (data.isFlaggedFraud==1)]
flagged_fraud_records
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2736446   212  TRANSFER  365423.309   C728984460    1822508.289
# 3247297   250  TRANSFER  365423.309  C1100582606    1343002.080
# 3760288   279  TRANSFER  365423.309  C1035541766     536624.410
# 5563713   387  TRANSFER  365423.309   C908544136    1822508.289
# 5996407   425  TRANSFER  365423.309   C689608084    1822508.289
# 5996409   425  TRANSFER  365423.309   C452586515    1822508.289
# 6168499   554  TRANSFER  365423.309   C193696150    1822508.289
# 6205439   586  TRANSFER  353874.220  C1684585475     353874.220
# 6266413   617  TRANSFER  365423.309   C786455622    1822508.289
# 6281482   646  TRANSFER  365423.309    C19004745    1822508.289
# 6281484   646  TRANSFER  365423.309   C724693370    1822508.289
# 6296014   671  TRANSFER  365423.309   C917414431    1822508.289
# 6351225   702  TRANSFER  365423.309  C1892216157    1822508.289
# 6362460   730  TRANSFER  365423.309  C2140038573    1822508.289
# ...

# %%
flagged_fraud_records.shape
# Out:
# (16, 11)

# %%
total_fraud= data[data.isFraud ==1]
total_fraud = total_fraud.shape[0]
total_fraud
# Out:
# 8213

# %%
total_isflaggedFraud= flagged_fraud_records.shape[0]
total_isflaggedFraud
# Out:
# 16

# %%
flagged_percent = total_isflaggedFraud/total_fraud * 100
print('Percentage of flagged fraud: ',round(flagged_percent,3))

unflagged_percent= (total_fraud-total_isflaggedFraud)/total_fraud * 100
print('Percentage of incorrectly flagged fraud: ',round(unflagged_percent,3))
# Out:
# Percentage of flagged fraud:  0.195
# Percentage of incorrectly flagged fraud:  99.805

# %%
total_transactions = data.shape[0]

fraud_transaction = data[data.isFraud==1].shape[0]

fraud_percent= fraud_transaction/total_transactions * 100
fraud_percent
# Out:
# 0.12908204481801522

# %%
print('Total transactions: ',total_transactions)
print('Total fraud transactions happened: ',fraud_transaction)
print("Total fraud transaction percent: ",round(fraud_percent,2))
# Out:
# Total transactions:  6362620
# Total fraud transactions happened:  8213
# Total fraud transaction percent:  0.13

# %%
fraud_amount= data[data.isFraud==1]
fraud_amount=fraud_amount.sort_values(by=['amount'],ascending=False)
fraud_amount
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362619   743  CASH_OUT  365423.309  C1280323807     850002.520
# 6362618   743  TRANSFER  365423.309  C1685995037     850002.520
# 6362617   743  CASH_OUT  365423.309  C1162922333    1822508.289
# 6362616   743  TRANSFER  365423.309  C1529008245    1822508.289
# 6362613   743  CASH_OUT  365423.309  C1436118706    1258818.820
# ...       ...       ...         ...          ...            ...
# 6181420   566  CASH_OUT    4501.300  C1848080177       1828.600
# 3958614   289  TRANSFER    4501.300    C32426691       3374.250
# 3958615   289  CASH_OUT    4501.300   C501091944       3374.250
# 6202688   583  TRANSFER    4501.300   C469202951       1583.280
# 6078960   519  TRANSFER    4501.300  C1153466023       1558.460
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362619             0.0   C873221189     2914266.669     3194869.671        1
# ...

# %%
plt.figure(figsize=(12, 6))
fraud_amount.amount.plot(
    kind='hist',
    bins=15,
    color='orange',
    edgecolor='black',
    alpha=0.8
)

plt.title('Distribution of Fraudulent Amounts', fontsize=16)
plt.xlabel('Amount', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

plt.show()

# %%
fraudster= data.nameDest.value_counts()
fraudster
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C1590550415    101
#               ...
# M295304806       1
# M33419717        1
# M1940055334      1
# M335107734       1
# M1757317128      1
# Name: count, Length: 2722362, dtype: int64

# %%
fraudster[:10]
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C1590550415    101
# C248609774     101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraudster[:10].plot(
    kind='barh',
    figsize=(10, 6),
    color='orange',
    edgecolor='black',
    alpha=0.8
)

plt.title('Top 10 Fraudster Data', fontsize=16)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Index', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.histplot(data['step'], bins=50, kde=True, color='skyblue', edgecolor='black', alpha=0.7)

plt.title('Distribution of Step', fontsize=16)
plt.xlabel('Step', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

plt.show()

# %%
numeric_data = data.select_dtypes(include=['number'])

corr = numeric_data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(
    corr,
    xticklabels=corr.columns,
    yticklabels=corr.columns,
    annot=True,
    cmap='Blues',
    fmt=".3f",
    linewidths=0.5,
    cbar_kws={'shrink': 0.8}
)

plt.title("Correlation Matrix", fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

plt.show()

# %% [markdown]
# Data Preprocessing

# %%
data.isFraud.value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
fraud_counts = data.isFraud.value_counts()

plt.figure(figsize=(8, 8))
plt.pie(
    fraud_counts,
    labels=fraud_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['skyblue', 'salmon'],
    pctdistance=0.85,
    textprops={'fontsize': 12}
)

centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Fraud vs Non-Fraud Transactions', fontsize=16)
plt.tight_layout()

plt.show()

# %%
# class count
class_count_0, class_count_1 = data['isFraud'].value_counts()

# Separate class
class_0 = data[data['isFraud'] == 0]
class_1 = data[data['isFraud'] == 1]# print the shape of the class
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (6354407, 11)
# class 1: (8213, 11)

# %% [markdown]
# Under Sampling technique

# %%
class_0_under = class_0.sample(class_count_1)
balanced_data = pd.concat([class_0_under, class_1], axis=0)

print("Total count of class 0 and class 1:")
print(balanced_data['isFraud'].value_counts())

plt.figure(figsize=(8, 6))
balanced_data['isFraud'].value_counts().plot(
    kind='bar',
    color=['skyblue', 'salmon'],
    edgecolor='black',
    alpha=0.8
)

plt.title('Class Distribution After Undersampling', fontsize=16)
plt.xlabel('Class (isFraud)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()
# Out:
# Total count of class 0 and class 1:
# isFraud
# 0    8213
# 1    8213
# Name: count, dtype: int64

# %%
balanced_data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 1041586    94   CASH_IN  365423.309  C1848895482          0.000
# 2771380   213   CASH_IN  136379.710   C612285764    1467164.720
# 182194     13   PAYMENT   15959.260  C1623355084     531245.490
# 6029788   471   PAYMENT   26611.040  C1672745503          0.000
# 1639279   157   CASH_IN   32965.950  C1313981078      19960.000
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT  339682.130   C786484425     339682.130
# 6362616   743  TRANSFER  365423.309  C1529008245    1822508.289
# 6362617   743  CASH_OUT  365423.309  C1162922333    1822508.289
# 6362618   743  TRANSFER  365423.309  C1685995037     850002.520
# 6362619   743  CASH_OUT  365423.309  C1280323807     850002.520
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 1041586       453308.07   C741431520     2914266.669     3194869.671        0
# ...

# %%
balanced_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16426 entries, 1041586 to 6362619
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            16426 non-null  int64
#  1   type            16426 non-null  object
#  2   amount          16426 non-null  float64
#  3   nameOrig        16426 non-null  object
#  4   oldbalanceOrg   16426 non-null  float64
#  5   newbalanceOrig  16426 non-null  float64
#  6   nameDest        16426 non-null  object
#  7   oldbalanceDest  16426 non-null  float64
#  8   newbalanceDest  16426 non-null  float64
#  9   isFraud         16426 non-null  int64
#  10  isFlaggedFraud  16426 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 1.5+ MB

# %%
balanced_data.type.unique()
# Out:
# array(['CASH_IN', 'PAYMENT', 'CASH_OUT', 'TRANSFER', 'DEBIT'],
#       dtype=object)

# %%
balanced_data["type"] = balanced_data["type"].map({"CASH_OUT": 1, "PAYMENT": 2, "CASH_IN": 3, "TRANSFER": 4, "DEBIT": 5})

# %%
balanced_data.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
X = balanced_data[['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig']].values
y = balanced_data['isFraud'].values

# %% [markdown]
# Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Standardize the Dataset

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()
scaler.fit(X_train)

print(scaler.mean_)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# [2.27214612e+00 1.89726994e+05 4.99820824e+05 1.60907887e+05]

# %%
from sklearn import preprocessing
from sklearn import utils

#convert y values to categorical values
lab = preprocessing.LabelEncoder()
y_train = lab.fit_transform(y_train)
y_test = lab.fit_transform(y_test)

# %% [markdown]
# Building the model and Fitting the Data¶

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, fbeta_score

# %%
models = {
    "LR": LogisticRegression(),
    "XGB": XGBClassifier(),
    "Naive Bayes": GaussianNB(),
    "SVC": SVC()

}

# %%
results = []

for name, model in models.items():
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    recall = recall_score(y_test, y_test_pred, average='micro')
    precision = precision_score(y_test, y_test_pred, average='micro')
    f1 = f1_score(y_test, y_test_pred, average='micro')
    fbeta = fbeta_score(y_test, y_test_pred, beta=0.5, average='micro')

    results.append({
        'Model': name,
        'Train Accuracy': train_accuracy,
        'Test Accuracy': test_accuracy,
        'Recall': recall,
        'Precision': precision,
        'F1 Score': f1,
        'F-Beta (β=0.5)': fbeta
    })

results_df = pd.DataFrame(results)
results_df
# Out:
#          Model  Train Accuracy  Test Accuracy    Recall  Precision  F1 Score  \
# 0           LR        0.899087       0.904747  0.904747   0.904747  0.904747
# 1          XGB        0.995129       0.994218  0.994218   0.994218  0.994218
# 2  Naive Bayes        0.781887       0.784540  0.784540   0.784540  0.784540
# 3          SVC        0.949848       0.947657  0.947657   0.947657  0.947657
#
#    F-Beta (β=0.5)
# 0        0.904747
# 1        0.994218
# 2        0.784540
# 3        0.947657

# %%
plt.figure(figsize=(12, 8))

results_df.set_index('Model').plot(
    kind='bar',
    figsize=(12, 8),
    colormap='viridis',
    edgecolor='black',
    alpha=0.8
)

plt.title('Performance Metrics Comparison of Models', fontsize=16)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Metrics', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Metrics', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
# Evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 99.42%
